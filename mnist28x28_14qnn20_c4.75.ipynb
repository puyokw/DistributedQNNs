# %%
# -*- coding: utf-8 -*-
# %matplotlib inline
import matplotlib.pyplot as plt

import math
import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score, log_loss
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import SVC

import torch
import torch.nn as nn
import torchvision
from torch.optim import Adam
import torchvision
from torchvision.transforms import v2

import warnings
import time

seed = 1001
np.random.seed(seed)
torch.manual_seed(seed)
torch.set_default_dtype(torch.float32)
warnings.simplefilter('ignore', UserWarning)

# %%
# !pip install torchquantum

# %%
import torchquantum as tq
from torchquantum.measurement import expval_joint_analytical

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# device = "cpu"
print(torch.cuda.device_count())
print([torch.cuda.get_device_name('cuda:'+str(i)) for i in range(torch.cuda.device_count())])
# Out:
# 1
# ['NVIDIA GeForce RTX 4090']

# %%
data = torchvision.datasets.MNIST(root='./data', train=True, download=True)
data_tr, label_tr = data.train_data, data.train_labels
data = torchvision.datasets.MNIST(root='./data', train=False, download=True)
data_te, label_te = data.test_data, data.test_labels
print(data_tr.shape, data_te.shape)
# Out:
# torch.Size([60000, 28, 28]) torch.Size([10000, 28, 28])

# %%
num = 10
for i in range(num):
    ax = plt.subplot(2,num//2,i+1)
    ax.imshow(data_tr[i].detach().numpy(), cmap='gray_r')

# %%
dataset_name = 'mnist'
n_qubits = 7 # data_tr.shape[1]
n_class = len(np.unique(label_tr))

# %%
class CoeffLayer(nn.Module):
    def __init__(self, coeff):
        super().__init__()
        self.coeff = torch.nn.Parameter(coeff)
    def forward(self, x):
        ret = x * self.coeff
        return ret

class ConstCoeffLayer(nn.Module):
    def __init__(self, coeff):
        super().__init__()
        self.coeff = coeff
    def forward(self, x):
        ret = x * self.coeff
        return ret

# %%
# 28x28 => 14x7x8 = 14x28x2
class QNNsubModel(nn.Module):
    def __init__(self):
        # params is numpy array
        super().__init__()
        self.n_wires=7
        self.encoder_gates = ([tq.functional.rx] * self.n_wires + [tq.functional.ry] * self.n_wires)*4
        self.n_block = 5
        self.n_depth_per_block = 20
        params = np.random.rand( self.n_wires*2*self.n_block*self.n_depth_per_block)*math.pi
        self.u_layers = tq.QuantumModuleList()
        for j in range(self.n_block*self.n_depth_per_block):
            for i in range(self.n_wires):
                self.u_layers.append( tq.RX(has_params=True, trainable=True, init_params=params[i+(2*j)*self.n_wires]) )
            for i in range(self.n_wires):
                self.u_layers.append( tq.RY(has_params=True, trainable=True, init_params=params[i+(2*j+1)*self.n_wires]) )

    def forward(self, x):
        bsz = x.shape[0]
        qdev = tq.QuantumDevice(
            n_wires=self.n_wires, bsz = bsz, device=x.device, record_op=False
        )
        ###
        n_depth_per_block = self.n_depth_per_block
        for nb in range(0,self.n_block-1): # 0, 1, 2, 3
            for k in range(n_depth_per_block):
                for j in range(2*nb*n_depth_per_block+2*k,2*nb*n_depth_per_block+2*k+2):
                    for i in range(self.n_wires):
                        self.u_layers[i+j*self.n_wires](qdev, wires=i)
                for i in range(self.n_wires):
                    qdev.cz(wires=[i,(i+1)%self.n_wires])
            # data encoding
            for j in range(2*nb,2*nb+2):
                for k in range(self.n_wires):
                    self.encoder_gates[k+j*self.n_wires](qdev, wires=k, params=x[:, k+j*self.n_wires])
            for i in range(self.n_wires):
                qdev.cz(wires=[i,(i+1)%self.n_wires])
        for nb in range(self.n_block-1,self.n_block): # 4
            for k in range(n_depth_per_block):
                for j in range(2*nb*n_depth_per_block+2*k,2*nb*n_depth_per_block+2*k+2):
                    for i in range(self.n_wires):
                        self.u_layers[i+j*self.n_wires](qdev, wires=i)
                if nb==self.n_block-1 and k==n_depth_per_block-1:
                    break
                for i in range(self.n_wires):
                    qdev.cz(wires=[i,(i+1)%self.n_wires])

        obs_list = [ expval_joint_analytical(qdev, "I"*(i)+Pauli+"I"*(self.n_wires-1-i)) for Pauli in ["X","Z"] for i in range(5)]
        # obs_list = [ expval_joint_analytical(qdev, "I"*(i)+Pauli+"I"*(self.n_wires-1-i)) for Pauli in ["X"] for i in range(10)]
        ret = torch.stack(obs_list, dim=1)
        return ret

# %%
class QNNModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.qnn0, self.qnn1, self.qnn2, self.qnn3 = QNNsubModel(), QNNsubModel(), QNNsubModel(), QNNsubModel()
        self.qnn4, self.qnn5, self.qnn6, self.qnn7 = QNNsubModel(), QNNsubModel(), QNNsubModel(), QNNsubModel()
        self.qnn8, self.qnn9, self.qnn10, self.qnn11 = QNNsubModel(), QNNsubModel(), QNNsubModel(), QNNsubModel()
        self.qnn12, self.qnn13 = QNNsubModel(), QNNsubModel()
    def forward(self, x):
        LEN = 56
        in_x = [ x[:,i*LEN:(i+1)*LEN] for i in range(14) ]
        ret0, ret1, ret2, ret3 = self.qnn0(in_x[0]), self.qnn1(in_x[1]), self.qnn2(in_x[2]), self.qnn3(in_x[3])
        ret4, ret5, ret6, ret7 = self.qnn4(in_x[4]), self.qnn5(in_x[5]), self.qnn6(in_x[6]), self.qnn7(in_x[7])
        ret8, ret9, ret10, ret11 = self.qnn8(in_x[8]), self.qnn9(in_x[9]), self.qnn10(in_x[10]), self.qnn11(in_x[11])
        ret12, ret13 = self.qnn12(in_x[12]), self.qnn13(in_x[13])
        ret = ret0 + ret1 + ret2 + ret3 \
            + ret4 + ret5 + ret6 + ret7 \
            + ret8 + ret9 + ret10 + ret11 \
            + ret12 + ret13
        return ret

# %%
def train(data, label, model, optimizer):
    optimizer.zero_grad()
    pred = model(data)
    loss = torch.nn.CrossEntropyLoss()(pred, label)
    loss.backward()
    optimizer.step()
    acc = (pred.argmax(axis=1) == label).sum().item() / len(label)
    # acc = accuracy_score(y_tr, pred.argmax(axis=1).cpu().detach().numpy() )
    print(f"train loss: {loss.item():.5f} train acc: {acc:.3f}", end='\n')
    return loss.item(), acc

def valid(data, label, model):
    with torch.no_grad():
        pred = model(data)
        loss = torch.nn.CrossEntropyLoss()(pred, label)
    acc = (pred.argmax(axis=1) == label).sum().item() / len(label)
    # acc = accuracy_score(y_te, pred.argmax(axis=1).cpu().detach().numpy() )
    print(f"valid loss: {loss.item():.5f} valid acc: {acc:.3f}", end='\n')
    return loss.item(), acc

# %%
data_tr = data_tr.reshape(-1,data_tr.shape[1]*data_tr.shape[2]).detach().numpy()
data_te = data_te.reshape(-1,data_te.shape[1]*data_te.shape[2]).detach().numpy()
data_tr = data_tr/255*math.pi/4
data_te = data_te/255*math.pi/4

data_tr = torch.from_numpy(data_tr)
data_te = torch.from_numpy(data_te)

# %%
all_all_fsteps = []
all_all_bsteps = []
all_all_vsteps = []

max_epochs = 50
lr = 5e-3

data_te, label_te = data_te.to(device), label_te.to(device)
model = torch.nn.Sequential(
    QNNModel(),
    ConstCoeffLayer(4.75),
    nn.Softmax(dim=1)
)
optimizer = Adam(model.parameters(), lr=lr, weight_decay=5e-5)
all_tr_loss = []
all_tr_acc = []

all_fsteps = []
all_bsteps = []
for i_epoch in range(max_epochs):
    tmp_skf = StratifiedKFold(n_splits=50) # for minibatch training
    # 60000/50 = 1200, 17min/epoch
    for i_fold, (_, tmp_te) in enumerate(tmp_skf.split(data_tr, label_tr)):
        print(f"{i_epoch}th epoch-{i_fold}th iteration:", end=" ")
        loss_tr, acc_tr = train(data_tr[tmp_te].to(device), label_tr[tmp_te].to(device), model, optimizer)
    all_tr_loss.append(loss_tr)
    all_tr_acc.append(acc_tr)
    loss_valid, acc_valid = valid(data_te, label_te, model)
    ###
# Out:
# 0th epoch-0th iteration: train loss: 2.31947 train acc: 0.079
# 0th epoch-1th iteration: train loss: 2.24449 train acc: 0.201
# 0th epoch-2th iteration: train loss: 2.25422 train acc: 0.195
# 0th epoch-3th iteration: train loss: 2.26974 train acc: 0.177
# 0th epoch-4th iteration: train loss: 2.17817 train acc: 0.278
# 0th epoch-5th iteration: train loss: 2.13827 train acc: 0.318
# 0th epoch-6th iteration: train loss: 2.10489 train acc: 0.346
# 0th epoch-7th iteration: train loss: 2.12629 train acc: 0.329
# 0th epoch-8th iteration: train loss: 2.08094 train acc: 0.366
# 0th epoch-9th iteration: train loss: 2.03593 train acc: 0.423
# 0th epoch-10th iteration: train loss: 2.02108 train acc: 0.439
# 0th epoch-11th iteration: train loss: 1.95891 train acc: 0.516
# 0th epoch-12th iteration: train loss: 2.00920 train acc: 0.450
# 0th epoch-13th iteration: train loss: 1.97749 train acc: 0.482
# 0th epoch-14th iteration: train loss: 1.93970 train acc: 0.526
# 0th epoch-15th iteration: train loss: 1.92144 train acc: 0.540
# 0th epoch-16th iteration: train loss: 1.92420 train acc: 0.544
# 0th epoch-17th iteration: train loss: 1.90337 train acc: 0.563
# 0th epoch-18th iteration: train loss: 1.91888 train acc: 0.553
# 0th epoch-19th iteration: train loss: 1.90169 train acc: 0.562
# 0th epoch-20th iteration: train loss: 1.89967 train acc: 0.562
# 0th epoch-21th iteration: train loss: 1.89647 train acc: 0.567
# 0th epoch-22th iteration: train loss: 1.90197 train acc: 0.558
# 0th epoch-23th iteration: train loss: 1.89194 train acc: 0.566
# 0th epoch-24th iteration: train loss: 1.91394 train acc: 0.545
# 0th epoch-25th iteration: train loss: 1.89684 train acc: 0.562
# 0th epoch-26th iteration: train loss: 1.90828 train acc: 0.553
# 0th epoch-27th iteration: train loss: 1.87794 train acc: 0.591
# 0th epoch-28th iteration: train loss: 1.86251 train acc: 0.608
# 0th epoch-29th iteration: train loss: 1.88362 train acc: 0.585
# 0th epoch-30th iteration: train loss: 1.86214 train acc: 0.608
# 0th epoch-31th iteration: train loss: 1.86207 train acc: 0.607
# 0th epoch-32th iteration: train loss: 1.84252 train acc: 0.627
# 0th epoch-33th iteration: train loss: 1.82917 train acc: 0.645
# 0th epoch-34th iteration: train loss: 1.83198 train acc: 0.639
# 0th epoch-35th iteration: train loss: 1.83318 train acc: 0.637
# 0th epoch-36th iteration: train loss: 1.82250 train acc: 0.645
# 0th epoch-37th iteration: train loss: 1.83261 train acc: 0.632
# 0th epoch-38th iteration: train loss: 1.82634 train acc: 0.636
# 0th epoch-39th iteration: train loss: 1.82047 train acc: 0.646
# 0th epoch-40th iteration: train loss: 1.82122 train acc: 0.634
# 0th epoch-41th iteration: train loss: 1.80856 train acc: 0.669
# 0th epoch-42th iteration: train loss: 1.78853 train acc: 0.701
# 0th epoch-43th iteration: train loss: 1.79514 train acc: 0.684
# 0th epoch-44th iteration: train loss: 1.76353 train acc: 0.714
# 0th epoch-45th iteration: train loss: 1.75022 train acc: 0.722
# 0th epoch-46th iteration: train loss: 1.73896 train acc: 0.733
# 0th epoch-47th iteration: train loss: 1.73848 train acc: 0.733
# 0th epoch-48th iteration: train loss: 1.71232 train acc: 0.760
# 0th epoch-49th iteration: train loss: 1.72092 train acc: 0.754
# valid loss: 1.75192 valid acc: 0.725
# 1th epoch-0th iteration: train loss: 1.75487 train acc: 0.717
# 1th epoch-1th iteration: train loss: 1.73160 train acc: 0.740
# 1th epoch-2th iteration: train loss: 1.72918 train acc: 0.745
# 1th epoch-3th iteration: train loss: 1.73900 train acc: 0.737
# 1th epoch-4th iteration: train loss: 1.73575 train acc: 0.736
# 1th epoch-5th iteration: train loss: 1.74602 train acc: 0.723
# 1th epoch-6th iteration: train loss: 1.74177 train acc: 0.735
# 1th epoch-7th iteration: train loss: 1.75041 train acc: 0.717
# 1th epoch-8th iteration: train loss: 1.72678 train acc: 0.749
# 1th epoch-9th iteration: train loss: 1.73726 train acc: 0.738
# 1th epoch-10th iteration: train loss: 1.73309 train acc: 0.746
# 1th epoch-11th iteration: train loss: 1.73908 train acc: 0.739
# 1th epoch-12th iteration: train loss: 1.75197 train acc: 0.720
# 1th epoch-13th iteration: train loss: 1.72372 train acc: 0.748
# 1th epoch-14th iteration: train loss: 1.73777 train acc: 0.734
# 1th epoch-15th iteration: train loss: 1.71245 train acc: 0.757
# 1th epoch-16th iteration: train loss: 1.73188 train acc: 0.741
# 1th epoch-17th iteration: train loss: 1.71753 train acc: 0.749
# 1th epoch-18th iteration: train loss: 1.72391 train acc: 0.747
# 1th epoch-19th iteration: train loss: 1.71978 train acc: 0.748
# 1th epoch-20th iteration: train loss: 1.72744 train acc: 0.743
# 1th epoch-21th iteration: train loss: 1.71283 train acc: 0.762
# 1th epoch-22th iteration: train loss: 1.72770 train acc: 0.744
# 1th epoch-23th iteration: train loss: 1.71958 train acc: 0.753
# 1th epoch-24th iteration: train loss: 1.72706 train acc: 0.749
# 1th epoch-25th iteration: train loss: 1.73100 train acc: 0.741
# 1th epoch-26th iteration: train loss: 1.74044 train acc: 0.729
# 1th epoch-27th iteration: train loss: 1.71300 train acc: 0.756
# 1th epoch-28th iteration: train loss: 1.71189 train acc: 0.757
# 1th epoch-29th iteration: train loss: 1.72532 train acc: 0.743
# 1th epoch-30th iteration: train loss: 1.72340 train acc: 0.747
# 1th epoch-31th iteration: train loss: 1.72032 train acc: 0.755
# 1th epoch-32th iteration: train loss: 1.71606 train acc: 0.759
# 1th epoch-33th iteration: train loss: 1.71577 train acc: 0.757
# 1th epoch-34th iteration: train loss: 1.71203 train acc: 0.762
# 1th epoch-35th iteration: train loss: 1.72258 train acc: 0.750
# 1th epoch-36th iteration: train loss: 1.71584 train acc: 0.756
# 1th epoch-37th iteration: train loss: 1.72201 train acc: 0.748
# 1th epoch-38th iteration: train loss: 1.72296 train acc: 0.749
# 1th epoch-39th iteration: train loss: 1.72373 train acc: 0.746
# 1th epoch-40th iteration: train loss: 1.71927 train acc: 0.754
# 1th epoch-41th iteration: train loss: 1.72188 train acc: 0.751
# 1th epoch-42th iteration: train loss: 1.72440 train acc: 0.753
# 1th epoch-43th iteration: train loss: 1.71577 train acc: 0.751
# 1th epoch-44th iteration: train loss: 1.71722 train acc: 0.751
# 1th epoch-45th iteration: train loss: 1.70395 train acc: 0.767
# 1th epoch-46th iteration: train loss: 1.70007 train acc: 0.772
# 1th epoch-47th iteration: train loss: 1.70337 train acc: 0.771
# 1th epoch-48th iteration: train loss: 1.68974 train acc: 0.776
# 1th epoch-49th iteration: train loss: 1.68941 train acc: 0.779
# valid loss: 1.71494 valid acc: 0.755
# 2th epoch-0th iteration: train loss: 1.71585 train acc: 0.753
# 2th epoch-1th iteration: train loss: 1.70203 train acc: 0.767
# 2th epoch-2th iteration: train loss: 1.70058 train acc: 0.772
# 2th epoch-3th iteration: train loss: 1.70361 train acc: 0.767
# 2th epoch-4th iteration: train loss: 1.70699 train acc: 0.762
# 2th epoch-5th iteration: train loss: 1.71977 train acc: 0.748
# 2th epoch-6th iteration: train loss: 1.71386 train acc: 0.758
# 2th epoch-7th iteration: train loss: 1.72183 train acc: 0.750
# 2th epoch-8th iteration: train loss: 1.70552 train acc: 0.765
# 2th epoch-9th iteration: train loss: 1.71344 train acc: 0.761
# 2th epoch-10th iteration: train loss: 1.70948 train acc: 0.757
# 2th epoch-11th iteration: train loss: 1.71052 train acc: 0.759
# 2th epoch-12th iteration: train loss: 1.71786 train acc: 0.751
# 2th epoch-13th iteration: train loss: 1.70561 train acc: 0.765
# 2th epoch-14th iteration: train loss: 1.69594 train acc: 0.780
# 2th epoch-15th iteration: train loss: 1.64787 train acc: 0.825
# 2th epoch-16th iteration: train loss: 1.64878 train acc: 0.838
# 2th epoch-17th iteration: train loss: 1.66880 train acc: 0.811
# 2th epoch-18th iteration: train loss: 1.63167 train acc: 0.847
# 2th epoch-19th iteration: train loss: 1.63928 train acc: 0.833
# 2th epoch-20th iteration: train loss: 1.64654 train acc: 0.829
# 2th epoch-21th iteration: train loss: 1.63931 train acc: 0.836
# 2th epoch-22th iteration: train loss: 1.64470 train acc: 0.829
# 2th epoch-23th iteration: train loss: 1.62603 train acc: 0.853
# 2th epoch-24th iteration: train loss: 1.63527 train acc: 0.844
# 2th epoch-25th iteration: train loss: 1.64229 train acc: 0.839
# 2th epoch-26th iteration: train loss: 1.64921 train acc: 0.829
# 2th epoch-27th iteration: train loss: 1.62983 train acc: 0.849
# 2th epoch-28th iteration: train loss: 1.62650 train acc: 0.850
# 2th epoch-29th iteration: train loss: 1.63650 train acc: 0.846
# 2th epoch-30th iteration: train loss: 1.63216 train acc: 0.853
# 2th epoch-31th iteration: train loss: 1.63031 train acc: 0.853
# 2th epoch-32th iteration: train loss: 1.63640 train acc: 0.843
# 2th epoch-33th iteration: train loss: 1.62458 train acc: 0.856
# 2th epoch-34th iteration: train loss: 1.63578 train acc: 0.843
# 2th epoch-35th iteration: train loss: 1.63926 train acc: 0.841
# 2th epoch-36th iteration: train loss: 1.62890 train acc: 0.851
# 2th epoch-37th iteration: train loss: 1.62648 train acc: 0.849
# 2th epoch-38th iteration: train loss: 1.63239 train acc: 0.843
# 2th epoch-39th iteration: train loss: 1.63130 train acc: 0.845
# 2th epoch-40th iteration: train loss: 1.62414 train acc: 0.855
# 2th epoch-41th iteration: train loss: 1.63158 train acc: 0.850
# 2th epoch-42th iteration: train loss: 1.63066 train acc: 0.843
# 2th epoch-43th iteration: train loss: 1.62456 train acc: 0.846
# 2th epoch-44th iteration: train loss: 1.62748 train acc: 0.848
# 2th epoch-45th iteration: train loss: 1.61151 train acc: 0.866
# 2th epoch-46th iteration: train loss: 1.60911 train acc: 0.864
# 2th epoch-47th iteration: train loss: 1.61069 train acc: 0.863
# 2th epoch-48th iteration: train loss: 1.60242 train acc: 0.873
# 2th epoch-49th iteration: train loss: 1.59971 train acc: 0.868
# valid loss: 1.62001 valid acc: 0.853
# 3th epoch-0th iteration: train loss: 1.62197 train acc: 0.853
# 3th epoch-1th iteration: train loss: 1.60854 train acc: 0.869
# 3th epoch-2th iteration: train loss: 1.60934 train acc: 0.863
# 3th epoch-3th iteration: train loss: 1.61251 train acc: 0.861
# 3th epoch-4th iteration: train loss: 1.61129 train acc: 0.863
# 3th epoch-5th iteration: train loss: 1.62250 train acc: 0.855
# 3th epoch-6th iteration: train loss: 1.62233 train acc: 0.860
# 3th epoch-7th iteration: train loss: 1.63166 train acc: 0.843
# 3th epoch-8th iteration: train loss: 1.61154 train acc: 0.866
# 3th epoch-9th iteration: train loss: 1.62143 train acc: 0.851
# 3th epoch-10th iteration: train loss: 1.61649 train acc: 0.855
# 3th epoch-11th iteration: train loss: 1.61853 train acc: 0.856
# 3th epoch-12th iteration: train loss: 1.62368 train acc: 0.852
# 3th epoch-13th iteration: train loss: 1.61565 train acc: 0.856
# 3th epoch-14th iteration: train loss: 1.61866 train acc: 0.865
# 3th epoch-15th iteration: train loss: 1.60613 train acc: 0.863
# 3th epoch-16th iteration: train loss: 1.61664 train acc: 0.857
# 3th epoch-17th iteration: train loss: 1.60795 train acc: 0.862
# 3th epoch-18th iteration: train loss: 1.60889 train acc: 0.866
# 3th epoch-19th iteration: train loss: 1.60789 train acc: 0.863
# 3th epoch-20th iteration: train loss: 1.61486 train acc: 0.860
# 3th epoch-21th iteration: train loss: 1.60902 train acc: 0.866
# 3th epoch-22th iteration: train loss: 1.61996 train acc: 0.849
# 3th epoch-23th iteration: train loss: 1.61001 train acc: 0.864
# 3th epoch-24th iteration: train loss: 1.61232 train acc: 0.866
# 3th epoch-25th iteration: train loss: 1.61830 train acc: 0.863
# 3th epoch-26th iteration: train loss: 1.62726 train acc: 0.849
# 3th epoch-27th iteration: train loss: 1.60852 train acc: 0.867
# 3th epoch-28th iteration: train loss: 1.60303 train acc: 0.873
# 3th epoch-29th iteration: train loss: 1.60607 train acc: 0.871
# 3th epoch-30th iteration: train loss: 1.58199 train acc: 0.907
# 3th epoch-31th iteration: train loss: 1.62418 train acc: 0.880
# 3th epoch-32th iteration: train loss: 1.58032 train acc: 0.900
# 3th epoch-33th iteration: train loss: 1.57504 train acc: 0.910
# 3th epoch-34th iteration: train loss: 1.58211 train acc: 0.897
# 3th epoch-35th iteration: train loss: 1.58352 train acc: 0.899
# 3th epoch-36th iteration: train loss: 1.55275 train acc: 0.929
# 3th epoch-37th iteration: train loss: 1.55648 train acc: 0.929
# 3th epoch-38th iteration: train loss: 1.55954 train acc: 0.925
# 3th epoch-39th iteration: train loss: 1.56572 train acc: 0.916
# 3th epoch-40th iteration: train loss: 1.55386 train acc: 0.934
# 3th epoch-41th iteration: train loss: 1.56408 train acc: 0.923
# 3th epoch-42th iteration: train loss: 1.55965 train acc: 0.922
# 3th epoch-43th iteration: train loss: 1.55551 train acc: 0.927
# 3th epoch-44th iteration: train loss: 1.55478 train acc: 0.927
# 3th epoch-45th iteration: train loss: 1.54037 train acc: 0.947
# 3th epoch-46th iteration: train loss: 1.53235 train acc: 0.948
# 3th epoch-47th iteration: train loss: 1.54202 train acc: 0.938
# 3th epoch-48th iteration: train loss: 1.51869 train acc: 0.963
# 3th epoch-49th iteration: train loss: 1.51681 train acc: 0.958
# valid loss: 1.54336 valid acc: 0.938
# 4th epoch-0th iteration: train loss: 1.55493 train acc: 0.933
# 4th epoch-1th iteration: train loss: 1.53635 train acc: 0.941
# 4th epoch-2th iteration: train loss: 1.53090 train acc: 0.956
# 4th epoch-3th iteration: train loss: 1.53731 train acc: 0.947
# 4th epoch-4th iteration: train loss: 1.53245 train acc: 0.947
# 4th epoch-5th iteration: train loss: 1.53771 train acc: 0.949
# 4th epoch-6th iteration: train loss: 1.54314 train acc: 0.938
# 4th epoch-7th iteration: train loss: 1.56103 train acc: 0.919
# 4th epoch-8th iteration: train loss: 1.52220 train acc: 0.960
# 4th epoch-9th iteration: train loss: 1.54423 train acc: 0.934
# 4th epoch-10th iteration: train loss: 1.55114 train acc: 0.929
# 4th epoch-11th iteration: train loss: 1.54545 train acc: 0.938
# 4th epoch-12th iteration: train loss: 1.54315 train acc: 0.941
# 4th epoch-13th iteration: train loss: 1.53648 train acc: 0.939
# 4th epoch-14th iteration: train loss: 1.53971 train acc: 0.943
# 4th epoch-15th iteration: train loss: 1.52512 train acc: 0.948
# 4th epoch-16th iteration: train loss: 1.52786 train acc: 0.950
# 4th epoch-17th iteration: train loss: 1.52472 train acc: 0.951
# 4th epoch-18th iteration: train loss: 1.53137 train acc: 0.951
# 4th epoch-19th iteration: train loss: 1.52516 train acc: 0.953
# 4th epoch-20th iteration: train loss: 1.53781 train acc: 0.942
# 4th epoch-21th iteration: train loss: 1.52555 train acc: 0.956
# 4th epoch-22th iteration: train loss: 1.54644 train acc: 0.934
# 4th epoch-23th iteration: train loss: 1.52806 train acc: 0.953
# 4th epoch-24th iteration: train loss: 1.53358 train acc: 0.950
# 4th epoch-25th iteration: train loss: 1.54431 train acc: 0.942
# 4th epoch-26th iteration: train loss: 1.54573 train acc: 0.935
# 4th epoch-27th iteration: train loss: 1.52433 train acc: 0.955
# 4th epoch-28th iteration: train loss: 1.52255 train acc: 0.960
# 4th epoch-29th iteration: train loss: 1.52728 train acc: 0.950
# 4th epoch-30th iteration: train loss: 1.53254 train acc: 0.948
# 4th epoch-31th iteration: train loss: 1.53526 train acc: 0.943
# 4th epoch-32th iteration: train loss: 1.53562 train acc: 0.942
# 4th epoch-33th iteration: train loss: 1.52158 train acc: 0.958
# 4th epoch-34th iteration: train loss: 1.53304 train acc: 0.947
# 4th epoch-35th iteration: train loss: 1.54114 train acc: 0.944
# 4th epoch-36th iteration: train loss: 1.52664 train acc: 0.956
# 4th epoch-37th iteration: train loss: 1.53239 train acc: 0.948
# 4th epoch-38th iteration: train loss: 1.53389 train acc: 0.953
# 4th epoch-39th iteration: train loss: 1.53554 train acc: 0.943
# 4th epoch-40th iteration: train loss: 1.53554 train acc: 0.944
# 4th epoch-41th iteration: train loss: 1.54068 train acc: 0.943
# 4th epoch-42th iteration: train loss: 1.53448 train acc: 0.952
# 4th epoch-43th iteration: train loss: 1.54393 train acc: 0.930
# 4th epoch-44th iteration: train loss: 1.53612 train acc: 0.943
# 4th epoch-45th iteration: train loss: 1.52059 train acc: 0.956
# 4th epoch-46th iteration: train loss: 1.51388 train acc: 0.961
# 4th epoch-47th iteration: train loss: 1.52093 train acc: 0.963
# 4th epoch-48th iteration: train loss: 1.50852 train acc: 0.972
# 4th epoch-49th iteration: train loss: 1.50683 train acc: 0.971
# valid loss: 1.52737 valid acc: 0.951
# 5th epoch-0th iteration: train loss: 1.53347 train acc: 0.949
# 5th epoch-1th iteration: train loss: 1.51518 train acc: 0.965
# 5th epoch-2th iteration: train loss: 1.51554 train acc: 0.956
# 5th epoch-3th iteration: train loss: 1.52301 train acc: 0.953
# 5th epoch-4th iteration: train loss: 1.52033 train acc: 0.958
# 5th epoch-5th iteration: train loss: 1.53027 train acc: 0.953
# 5th epoch-6th iteration: train loss: 1.53003 train acc: 0.958
# 5th epoch-7th iteration: train loss: 1.54996 train acc: 0.937
# 5th epoch-8th iteration: train loss: 1.51744 train acc: 0.961
# 5th epoch-9th iteration: train loss: 1.53206 train acc: 0.947
# 5th epoch-10th iteration: train loss: 1.54177 train acc: 0.936
# 5th epoch-11th iteration: train loss: 1.53636 train acc: 0.944
# 5th epoch-12th iteration: train loss: 1.53616 train acc: 0.943
# 5th epoch-13th iteration: train loss: 1.52894 train acc: 0.948
# 5th epoch-14th iteration: train loss: 1.53362 train acc: 0.955
# 5th epoch-15th iteration: train loss: 1.51755 train acc: 0.960
# 5th epoch-16th iteration: train loss: 1.52068 train acc: 0.958
# 5th epoch-17th iteration: train loss: 1.52121 train acc: 0.957
# 5th epoch-18th iteration: train loss: 1.52631 train acc: 0.953
# 5th epoch-19th iteration: train loss: 1.51707 train acc: 0.963
# 5th epoch-20th iteration: train loss: 1.53054 train acc: 0.952
# 5th epoch-21th iteration: train loss: 1.52143 train acc: 0.958
# 5th epoch-22th iteration: train loss: 1.53937 train acc: 0.937
# 5th epoch-23th iteration: train loss: 1.52269 train acc: 0.958
# 5th epoch-24th iteration: train loss: 1.53263 train acc: 0.949
# 5th epoch-25th iteration: train loss: 1.54208 train acc: 0.942
# 5th epoch-26th iteration: train loss: 1.53956 train acc: 0.942
# 5th epoch-27th iteration: train loss: 1.51985 train acc: 0.953
# 5th epoch-28th iteration: train loss: 1.51870 train acc: 0.965
# 5th epoch-29th iteration: train loss: 1.52708 train acc: 0.953
# 5th epoch-30th iteration: train loss: 1.52757 train acc: 0.956
# 5th epoch-31th iteration: train loss: 1.53216 train acc: 0.948
# 5th epoch-32th iteration: train loss: 1.53359 train acc: 0.943
# 5th epoch-33th iteration: train loss: 1.52009 train acc: 0.963
# 5th epoch-34th iteration: train loss: 1.53060 train acc: 0.953
# 5th epoch-35th iteration: train loss: 1.53497 train acc: 0.948
# 5th epoch-36th iteration: train loss: 1.52397 train acc: 0.958
# 5th epoch-37th iteration: train loss: 1.53182 train acc: 0.948
# 5th epoch-38th iteration: train loss: 1.53063 train acc: 0.957
# 5th epoch-39th iteration: train loss: 1.52958 train acc: 0.950
# 5th epoch-40th iteration: train loss: 1.53330 train acc: 0.946
# 5th epoch-41th iteration: train loss: 1.54030 train acc: 0.942
# 5th epoch-42th iteration: train loss: 1.52941 train acc: 0.955
# 5th epoch-43th iteration: train loss: 1.53550 train acc: 0.939
# 5th epoch-44th iteration: train loss: 1.53198 train acc: 0.945
# 5th epoch-45th iteration: train loss: 1.51969 train acc: 0.959
# 5th epoch-46th iteration: train loss: 1.51278 train acc: 0.963
# 5th epoch-47th iteration: train loss: 1.51808 train acc: 0.966
# 5th epoch-48th iteration: train loss: 1.50198 train acc: 0.978
# 5th epoch-49th iteration: train loss: 1.50451 train acc: 0.972
# valid loss: 1.52815 valid acc: 0.949
# 6th epoch-0th iteration: train loss: 1.53228 train acc: 0.948
# 6th epoch-1th iteration: train loss: 1.51248 train acc: 0.972
# 6th epoch-2th iteration: train loss: 1.51227 train acc: 0.963
# 6th epoch-3th iteration: train loss: 1.51740 train acc: 0.962
# 6th epoch-4th iteration: train loss: 1.51988 train acc: 0.960
# 6th epoch-5th iteration: train loss: 1.53071 train acc: 0.953
# 6th epoch-6th iteration: train loss: 1.52738 train acc: 0.957
# 6th epoch-7th iteration: train loss: 1.54214 train acc: 0.943
# 6th epoch-8th iteration: train loss: 1.51995 train acc: 0.963
# 6th epoch-9th iteration: train loss: 1.52897 train acc: 0.954
# 6th epoch-10th iteration: train loss: 1.53894 train acc: 0.943
# 6th epoch-11th iteration: train loss: 1.53258 train acc: 0.951
# 6th epoch-12th iteration: train loss: 1.53268 train acc: 0.945
# 6th epoch-13th iteration: train loss: 1.53029 train acc: 0.948
# 6th epoch-14th iteration: train loss: 1.53068 train acc: 0.958
# 6th epoch-15th iteration: train loss: 1.51506 train acc: 0.959
# 6th epoch-16th iteration: train loss: 1.51982 train acc: 0.958
# 6th epoch-17th iteration: train loss: 1.52246 train acc: 0.953
# 6th epoch-18th iteration: train loss: 1.52804 train acc: 0.951
# 6th epoch-19th iteration: train loss: 1.51519 train acc: 0.962
# 6th epoch-20th iteration: train loss: 1.52476 train acc: 0.958
# 6th epoch-21th iteration: train loss: 1.51863 train acc: 0.961
# 6th epoch-22th iteration: train loss: 1.54169 train acc: 0.935
# 6th epoch-23th iteration: train loss: 1.52199 train acc: 0.954
# 6th epoch-24th iteration: train loss: 1.52637 train acc: 0.951
# 6th epoch-25th iteration: train loss: 1.53672 train acc: 0.949
# 6th epoch-26th iteration: train loss: 1.53879 train acc: 0.940
# 6th epoch-27th iteration: train loss: 1.51799 train acc: 0.958
# 6th epoch-28th iteration: train loss: 1.51253 train acc: 0.967
# 6th epoch-29th iteration: train loss: 1.52114 train acc: 0.958
# 6th epoch-30th iteration: train loss: 1.52489 train acc: 0.960
# 6th epoch-31th iteration: train loss: 1.53135 train acc: 0.951
# 6th epoch-32th iteration: train loss: 1.52630 train acc: 0.952
# 6th epoch-33th iteration: train loss: 1.51536 train acc: 0.965
# 6th epoch-34th iteration: train loss: 1.52830 train acc: 0.956
# 6th epoch-35th iteration: train loss: 1.53169 train acc: 0.951
# 6th epoch-36th iteration: train loss: 1.52141 train acc: 0.958
# 6th epoch-37th iteration: train loss: 1.52568 train acc: 0.955
# 6th epoch-38th iteration: train loss: 1.52697 train acc: 0.962
# 6th epoch-39th iteration: train loss: 1.52781 train acc: 0.951
# 6th epoch-40th iteration: train loss: 1.52723 train acc: 0.952
# 6th epoch-41th iteration: train loss: 1.53360 train acc: 0.950
# 6th epoch-42th iteration: train loss: 1.52425 train acc: 0.957
# 6th epoch-43th iteration: train loss: 1.53289 train acc: 0.942
# 6th epoch-44th iteration: train loss: 1.52757 train acc: 0.950
# 6th epoch-45th iteration: train loss: 1.51199 train acc: 0.968
# 6th epoch-46th iteration: train loss: 1.50929 train acc: 0.967
# 6th epoch-47th iteration: train loss: 1.51684 train acc: 0.962
# 6th epoch-48th iteration: train loss: 1.50016 train acc: 0.976
# 6th epoch-49th iteration: train loss: 1.50216 train acc: 0.974
# valid loss: 1.52459 valid acc: 0.953
# 7th epoch-0th iteration: train loss: 1.52740 train acc: 0.951
# 7th epoch-1th iteration: train loss: 1.51056 train acc: 0.973
# 7th epoch-2th iteration: train loss: 1.51107 train acc: 0.965
# 7th epoch-3th iteration: train loss: 1.51353 train acc: 0.967
# 7th epoch-4th iteration: train loss: 1.51782 train acc: 0.961
# 7th epoch-5th iteration: train loss: 1.52399 train acc: 0.959
# 7th epoch-6th iteration: train loss: 1.52333 train acc: 0.958
# 7th epoch-7th iteration: train loss: 1.53845 train acc: 0.944
# 7th epoch-8th iteration: train loss: 1.51488 train acc: 0.965
# 7th epoch-9th iteration: train loss: 1.52371 train acc: 0.956
# 7th epoch-10th iteration: train loss: 1.53573 train acc: 0.942
# 7th epoch-11th iteration: train loss: 1.53141 train acc: 0.948
# 7th epoch-12th iteration: train loss: 1.53038 train acc: 0.948
# 7th epoch-13th iteration: train loss: 1.52587 train acc: 0.953
# 7th epoch-14th iteration: train loss: 1.52758 train acc: 0.963
# 7th epoch-15th iteration: train loss: 1.51334 train acc: 0.965
# 7th epoch-16th iteration: train loss: 1.51766 train acc: 0.959
# 7th epoch-17th iteration: train loss: 1.51910 train acc: 0.956
# 7th epoch-18th iteration: train loss: 1.52401 train acc: 0.953
# 7th epoch-19th iteration: train loss: 1.51268 train acc: 0.964
# 7th epoch-20th iteration: train loss: 1.52297 train acc: 0.960
# 7th epoch-21th iteration: train loss: 1.51711 train acc: 0.963
# 7th epoch-22th iteration: train loss: 1.53704 train acc: 0.941
# 7th epoch-23th iteration: train loss: 1.51851 train acc: 0.959
# 7th epoch-24th iteration: train loss: 1.52665 train acc: 0.953
# 7th epoch-25th iteration: train loss: 1.53673 train acc: 0.951
# 7th epoch-26th iteration: train loss: 1.53531 train acc: 0.943
# 7th epoch-27th iteration: train loss: 1.51498 train acc: 0.961
# 7th epoch-28th iteration: train loss: 1.51085 train acc: 0.969
# 7th epoch-29th iteration: train loss: 1.52089 train acc: 0.956
# 7th epoch-30th iteration: train loss: 1.52342 train acc: 0.962
# 7th epoch-31th iteration: train loss: 1.52996 train acc: 0.949
# 7th epoch-32th iteration: train loss: 1.52587 train acc: 0.953
# 7th epoch-33th iteration: train loss: 1.51334 train acc: 0.968
# 7th epoch-34th iteration: train loss: 1.52690 train acc: 0.952
# 7th epoch-35th iteration: train loss: 1.52889 train acc: 0.955
# 7th epoch-36th iteration: train loss: 1.51934 train acc: 0.957
# 7th epoch-37th iteration: train loss: 1.52692 train acc: 0.957
# 7th epoch-38th iteration: train loss: 1.52650 train acc: 0.958
# 7th epoch-39th iteration: train loss: 1.52566 train acc: 0.953
# 7th epoch-40th iteration: train loss: 1.52755 train acc: 0.952
# 7th epoch-41th iteration: train loss: 1.53286 train acc: 0.951
# 7th epoch-42th iteration: train loss: 1.52188 train acc: 0.958
# 7th epoch-43th iteration: train loss: 1.53100 train acc: 0.947
# 7th epoch-44th iteration: train loss: 1.52718 train acc: 0.954
# 7th epoch-45th iteration: train loss: 1.51221 train acc: 0.968
# 7th epoch-46th iteration: train loss: 1.50894 train acc: 0.968
# 7th epoch-47th iteration: train loss: 1.51610 train acc: 0.962
# 7th epoch-48th iteration: train loss: 1.49965 train acc: 0.978
# 7th epoch-49th iteration: train loss: 1.50099 train acc: 0.975
# valid loss: 1.52504 valid acc: 0.953
# 8th epoch-0th iteration: train loss: 1.52751 train acc: 0.952
# 8th epoch-1th iteration: train loss: 1.51082 train acc: 0.974
# 8th epoch-2th iteration: train loss: 1.51037 train acc: 0.967
# 8th epoch-3th iteration: train loss: 1.51271 train acc: 0.968
# 8th epoch-4th iteration: train loss: 1.51797 train acc: 0.963
# 8th epoch-5th iteration: train loss: 1.52310 train acc: 0.962
# 8th epoch-6th iteration: train loss: 1.52177 train acc: 0.959
# 8th epoch-7th iteration: train loss: 1.53779 train acc: 0.944
# 8th epoch-8th iteration: train loss: 1.51283 train acc: 0.968
# 8th epoch-9th iteration: train loss: 1.52202 train acc: 0.962
# 8th epoch-10th iteration: train loss: 1.53332 train acc: 0.944
# 8th epoch-11th iteration: train loss: 1.53035 train acc: 0.947
# 8th epoch-12th iteration: train loss: 1.52964 train acc: 0.946
# 8th epoch-13th iteration: train loss: 1.52374 train acc: 0.955
# 8th epoch-14th iteration: train loss: 1.52528 train acc: 0.966
# 8th epoch-15th iteration: train loss: 1.51180 train acc: 0.967
# 8th epoch-16th iteration: train loss: 1.51627 train acc: 0.963
# 8th epoch-17th iteration: train loss: 1.51843 train acc: 0.959
# 8th epoch-18th iteration: train loss: 1.52232 train acc: 0.957
# 8th epoch-19th iteration: train loss: 1.51124 train acc: 0.965
# 8th epoch-20th iteration: train loss: 1.52163 train acc: 0.963
# 8th epoch-21th iteration: train loss: 1.51635 train acc: 0.965
# 8th epoch-22th iteration: train loss: 1.53518 train acc: 0.940
# 8th epoch-23th iteration: train loss: 1.51637 train acc: 0.963
# 8th epoch-24th iteration: train loss: 1.52571 train acc: 0.953
# 8th epoch-25th iteration: train loss: 1.53600 train acc: 0.950
# 8th epoch-26th iteration: train loss: 1.53405 train acc: 0.943
# 8th epoch-27th iteration: train loss: 1.51303 train acc: 0.963
# 8th epoch-28th iteration: train loss: 1.51042 train acc: 0.968
# 8th epoch-29th iteration: train loss: 1.52058 train acc: 0.958
# 8th epoch-30th iteration: train loss: 1.52159 train acc: 0.962
# 8th epoch-31th iteration: train loss: 1.52898 train acc: 0.953
# 8th epoch-32th iteration: train loss: 1.52526 train acc: 0.953
# 8th epoch-33th iteration: train loss: 1.51304 train acc: 0.968
# 8th epoch-34th iteration: train loss: 1.52571 train acc: 0.953
# 8th epoch-35th iteration: train loss: 1.52747 train acc: 0.953
# 8th epoch-36th iteration: train loss: 1.51869 train acc: 0.959
# 8th epoch-37th iteration: train loss: 1.52678 train acc: 0.955
# 8th epoch-38th iteration: train loss: 1.52583 train acc: 0.957
# 8th epoch-39th iteration: train loss: 1.52472 train acc: 0.953
# 8th epoch-40th iteration: train loss: 1.52636 train acc: 0.951
# 8th epoch-41th iteration: train loss: 1.53269 train acc: 0.952
# 8th epoch-42th iteration: train loss: 1.52051 train acc: 0.959
# 8th epoch-43th iteration: train loss: 1.52890 train acc: 0.952
# 8th epoch-44th iteration: train loss: 1.52655 train acc: 0.952
# 8th epoch-45th iteration: train loss: 1.51139 train acc: 0.970
# 8th epoch-46th iteration: train loss: 1.50915 train acc: 0.968
# 8th epoch-47th iteration: train loss: 1.51581 train acc: 0.965
# 8th epoch-48th iteration: train loss: 1.49860 train acc: 0.978
# 8th epoch-49th iteration: train loss: 1.50094 train acc: 0.975
# valid loss: 1.52538 valid acc: 0.954
# 9th epoch-0th iteration: train loss: 1.52746 train acc: 0.953
# 9th epoch-1th iteration: train loss: 1.51219 train acc: 0.971
# 9th epoch-2th iteration: train loss: 1.50997 train acc: 0.969
# 9th epoch-3th iteration: train loss: 1.51231 train acc: 0.966
# 9th epoch-4th iteration: train loss: 1.51836 train acc: 0.963
# 9th epoch-5th iteration: train loss: 1.52227 train acc: 0.962
# 9th epoch-6th iteration: train loss: 1.52130 train acc: 0.961
# 9th epoch-7th iteration: train loss: 1.53769 train acc: 0.945
# 9th epoch-8th iteration: train loss: 1.51137 train acc: 0.970
# 9th epoch-9th iteration: train loss: 1.52240 train acc: 0.964
# 9th epoch-10th iteration: train loss: 1.53282 train acc: 0.948
# 9th epoch-11th iteration: train loss: 1.52841 train acc: 0.949
# 9th epoch-12th iteration: train loss: 1.52879 train acc: 0.949
# 9th epoch-13th iteration: train loss: 1.52226 train acc: 0.955
# 9th epoch-14th iteration: train loss: 1.52373 train acc: 0.965
# 9th epoch-15th iteration: train loss: 1.51039 train acc: 0.967
# 9th epoch-16th iteration: train loss: 1.51486 train acc: 0.961
# 9th epoch-17th iteration: train loss: 1.51798 train acc: 0.960
# 9th epoch-18th iteration: train loss: 1.52175 train acc: 0.961
# 9th epoch-19th iteration: train loss: 1.50999 train acc: 0.968
# 9th epoch-20th iteration: train loss: 1.52067 train acc: 0.963
# 9th epoch-21th iteration: train loss: 1.51598 train acc: 0.964
# 9th epoch-22th iteration: train loss: 1.53491 train acc: 0.943
# 9th epoch-23th iteration: train loss: 1.51540 train acc: 0.963
# 9th epoch-24th iteration: train loss: 1.52413 train acc: 0.956
# 9th epoch-25th iteration: train loss: 1.53472 train acc: 0.953
# 9th epoch-26th iteration: train loss: 1.53404 train acc: 0.947
# 9th epoch-27th iteration: train loss: 1.51130 train acc: 0.968
# 9th epoch-28th iteration: train loss: 1.51023 train acc: 0.968
# 9th epoch-29th iteration: train loss: 1.51970 train acc: 0.958
# 9th epoch-30th iteration: train loss: 1.52052 train acc: 0.962
# 9th epoch-31th iteration: train loss: 1.52802 train acc: 0.955
# 9th epoch-32th iteration: train loss: 1.52466 train acc: 0.953
# 9th epoch-33th iteration: train loss: 1.51334 train acc: 0.970
# 9th epoch-34th iteration: train loss: 1.52494 train acc: 0.953
# 9th epoch-35th iteration: train loss: 1.52694 train acc: 0.949
# 9th epoch-36th iteration: train loss: 1.51844 train acc: 0.958
# 9th epoch-37th iteration: train loss: 1.52671 train acc: 0.953
# 9th epoch-38th iteration: train loss: 1.52526 train acc: 0.956
# 9th epoch-39th iteration: train loss: 1.52462 train acc: 0.952
# 9th epoch-40th iteration: train loss: 1.52449 train acc: 0.956
# 9th epoch-41th iteration: train loss: 1.53286 train acc: 0.951
# 9th epoch-42th iteration: train loss: 1.52046 train acc: 0.958
# 9th epoch-43th iteration: train loss: 1.52810 train acc: 0.952
# 9th epoch-44th iteration: train loss: 1.52648 train acc: 0.952
# 9th epoch-45th iteration: train loss: 1.51073 train acc: 0.969
# 9th epoch-46th iteration: train loss: 1.50903 train acc: 0.970
# 9th epoch-47th iteration: train loss: 1.51552 train acc: 0.968
# 9th epoch-48th iteration: train loss: 1.49785 train acc: 0.978
# 9th epoch-49th iteration: train loss: 1.50121 train acc: 0.973
# valid loss: 1.52526 valid acc: 0.953
# 10th epoch-0th iteration: train loss: 1.52703 train acc: 0.952
# 10th epoch-1th iteration: train loss: 1.51340 train acc: 0.968
# 10th epoch-2th iteration: train loss: 1.51019 train acc: 0.968
# 10th epoch-3th iteration: train loss: 1.51227 train acc: 0.968
# 10th epoch-4th iteration: train loss: 1.51814 train acc: 0.964
# 10th epoch-5th iteration: train loss: 1.52124 train acc: 0.965
# 10th epoch-6th iteration: train loss: 1.52195 train acc: 0.960
# 10th epoch-7th iteration: train loss: 1.53747 train acc: 0.947
# 10th epoch-8th iteration: train loss: 1.51038 train acc: 0.970
# 10th epoch-9th iteration: train loss: 1.52398 train acc: 0.961
# 10th epoch-10th iteration: train loss: 1.53318 train acc: 0.947
# 10th epoch-11th iteration: train loss: 1.52565 train acc: 0.954
# 10th epoch-12th iteration: train loss: 1.52753 train acc: 0.953
# 10th epoch-13th iteration: train loss: 1.52113 train acc: 0.958
# 10th epoch-14th iteration: train loss: 1.52379 train acc: 0.963
# 10th epoch-15th iteration: train loss: 1.50934 train acc: 0.972
# 10th epoch-16th iteration: train loss: 1.51379 train acc: 0.961
# 10th epoch-17th iteration: train loss: 1.51759 train acc: 0.959
# 10th epoch-18th iteration: train loss: 1.52173 train acc: 0.958
# 10th epoch-19th iteration: train loss: 1.50977 train acc: 0.969
# 10th epoch-20th iteration: train loss: 1.52012 train acc: 0.958
# 10th epoch-21th iteration: train loss: 1.51566 train acc: 0.967
# 10th epoch-22th iteration: train loss: 1.53546 train acc: 0.943
# 10th epoch-23th iteration: train loss: 1.51580 train acc: 0.963
# 10th epoch-24th iteration: train loss: 1.52167 train acc: 0.956
# 10th epoch-25th iteration: train loss: 1.53228 train acc: 0.953
# 10th epoch-26th iteration: train loss: 1.53446 train acc: 0.948
# 10th epoch-27th iteration: train loss: 1.50956 train acc: 0.970
# 10th epoch-28th iteration: train loss: 1.50979 train acc: 0.971
# 10th epoch-29th iteration: train loss: 1.51801 train acc: 0.962
# 10th epoch-30th iteration: train loss: 1.52024 train acc: 0.963
# 10th epoch-31th iteration: train loss: 1.52712 train acc: 0.955
# 10th epoch-32th iteration: train loss: 1.52393 train acc: 0.954
# 10th epoch-33th iteration: train loss: 1.51349 train acc: 0.969
# 10th epoch-34th iteration: train loss: 1.52408 train acc: 0.953
# 10th epoch-35th iteration: train loss: 1.52720 train acc: 0.948
# 10th epoch-36th iteration: train loss: 1.51832 train acc: 0.958
# 10th epoch-37th iteration: train loss: 1.52628 train acc: 0.951
# 10th epoch-38th iteration: train loss: 1.52418 train acc: 0.958
# 10th epoch-39th iteration: train loss: 1.52534 train acc: 0.952
# 10th epoch-40th iteration: train loss: 1.52290 train acc: 0.959
# 10th epoch-41th iteration: train loss: 1.53295 train acc: 0.953
# 10th epoch-42th iteration: train loss: 1.52048 train acc: 0.961
# 10th epoch-43th iteration: train loss: 1.52908 train acc: 0.947
# 10th epoch-44th iteration: train loss: 1.52667 train acc: 0.953
# 10th epoch-45th iteration: train loss: 1.51011 train acc: 0.970
# 10th epoch-46th iteration: train loss: 1.50782 train acc: 0.968
# 10th epoch-47th iteration: train loss: 1.51426 train acc: 0.971
# 10th epoch-48th iteration: train loss: 1.49802 train acc: 0.979
# 10th epoch-49th iteration: train loss: 1.50167 train acc: 0.972
# valid loss: 1.52411 valid acc: 0.955
# 11th epoch-0th iteration: train loss: 1.52536 train acc: 0.953
# 11th epoch-1th iteration: train loss: 1.51314 train acc: 0.966
# 11th epoch-2th iteration: train loss: 1.51079 train acc: 0.964
# 11th epoch-3th iteration: train loss: 1.51274 train acc: 0.967
# 11th epoch-4th iteration: train loss: 1.51782 train acc: 0.964
# 11th epoch-5th iteration: train loss: 1.51932 train acc: 0.964
# 11th epoch-6th iteration: train loss: 1.52256 train acc: 0.962
# 11th epoch-7th iteration: train loss: 1.53747 train acc: 0.946
# 11th epoch-8th iteration: train loss: 1.50988 train acc: 0.970
# 11th epoch-9th iteration: train loss: 1.52317 train acc: 0.959
# 11th epoch-10th iteration: train loss: 1.53242 train acc: 0.945
# 11th epoch-11th iteration: train loss: 1.52454 train acc: 0.955
# 11th epoch-12th iteration: train loss: 1.52622 train acc: 0.954
# 11th epoch-13th iteration: train loss: 1.51950 train acc: 0.960
# 11th epoch-14th iteration: train loss: 1.52410 train acc: 0.962
# 11th epoch-15th iteration: train loss: 1.50909 train acc: 0.972
# 11th epoch-16th iteration: train loss: 1.51318 train acc: 0.965
# 11th epoch-17th iteration: train loss: 1.51629 train acc: 0.961
# 11th epoch-18th iteration: train loss: 1.52028 train acc: 0.959
# 11th epoch-19th iteration: train loss: 1.51054 train acc: 0.963
# 11th epoch-20th iteration: train loss: 1.52091 train acc: 0.957
# 11th epoch-21th iteration: train loss: 1.51447 train acc: 0.967
# 11th epoch-22th iteration: train loss: 1.53336 train acc: 0.948
# 11th epoch-23th iteration: train loss: 1.51654 train acc: 0.963
# 11th epoch-24th iteration: train loss: 1.52034 train acc: 0.960
# 11th epoch-25th iteration: train loss: 1.52950 train acc: 0.954
# 11th epoch-26th iteration: train loss: 1.53315 train acc: 0.950
# 11th epoch-27th iteration: train loss: 1.50858 train acc: 0.970
# 11th epoch-28th iteration: train loss: 1.51005 train acc: 0.975
# 11th epoch-29th iteration: train loss: 1.51633 train acc: 0.963
# 11th epoch-30th iteration: train loss: 1.51927 train acc: 0.961
# 11th epoch-31th iteration: train loss: 1.52628 train acc: 0.955
# 11th epoch-32th iteration: train loss: 1.52438 train acc: 0.955
# 11th epoch-33th iteration: train loss: 1.51348 train acc: 0.968
# 11th epoch-34th iteration: train loss: 1.52344 train acc: 0.953
# 11th epoch-35th iteration: train loss: 1.52746 train acc: 0.946
# 11th epoch-36th iteration: train loss: 1.51791 train acc: 0.961
# 11th epoch-37th iteration: train loss: 1.52614 train acc: 0.953
# 11th epoch-38th iteration: train loss: 1.52267 train acc: 0.958
# 11th epoch-39th iteration: train loss: 1.52658 train acc: 0.949
# 11th epoch-40th iteration: train loss: 1.52251 train acc: 0.956
# 11th epoch-41th iteration: train loss: 1.53281 train acc: 0.951
# 11th epoch-42th iteration: train loss: 1.52038 train acc: 0.958
# 11th epoch-43th iteration: train loss: 1.52837 train acc: 0.950
# 11th epoch-44th iteration: train loss: 1.52661 train acc: 0.955
# 11th epoch-45th iteration: train loss: 1.51015 train acc: 0.970
# 11th epoch-46th iteration: train loss: 1.50605 train acc: 0.970
# 11th epoch-47th iteration: train loss: 1.51266 train acc: 0.971
# 11th epoch-48th iteration: train loss: 1.49834 train acc: 0.979
# 11th epoch-49th iteration: train loss: 1.50199 train acc: 0.971
# valid loss: 1.52275 valid acc: 0.955
# 12th epoch-0th iteration: train loss: 1.52370 train acc: 0.958
# 12th epoch-1th iteration: train loss: 1.51161 train acc: 0.969
# 12th epoch-2th iteration: train loss: 1.51112 train acc: 0.964
# 12th epoch-3th iteration: train loss: 1.51321 train acc: 0.965
# 12th epoch-4th iteration: train loss: 1.51880 train acc: 0.963
# 12th epoch-5th iteration: train loss: 1.51817 train acc: 0.961
# 12th epoch-6th iteration: train loss: 1.52193 train acc: 0.963
# 12th epoch-7th iteration: train loss: 1.53803 train acc: 0.945
# 12th epoch-8th iteration: train loss: 1.51051 train acc: 0.969
# 12th epoch-9th iteration: train loss: 1.51981 train acc: 0.957
# 12th epoch-10th iteration: train loss: 1.52992 train acc: 0.947
# 12th epoch-11th iteration: train loss: 1.52469 train acc: 0.958
# 12th epoch-12th iteration: train loss: 1.52550 train acc: 0.955
# 12th epoch-13th iteration: train loss: 1.51764 train acc: 0.962
# 12th epoch-14th iteration: train loss: 1.52224 train acc: 0.963
# 12th epoch-15th iteration: train loss: 1.50914 train acc: 0.972
# 12th epoch-16th iteration: train loss: 1.51320 train acc: 0.963
# 12th epoch-17th iteration: train loss: 1.51473 train acc: 0.962
# 12th epoch-18th iteration: train loss: 1.51804 train acc: 0.962
# 12th epoch-19th iteration: train loss: 1.51046 train acc: 0.963
# 12th epoch-20th iteration: train loss: 1.52106 train acc: 0.956
# 12th epoch-21th iteration: train loss: 1.51404 train acc: 0.969
# 12th epoch-22th iteration: train loss: 1.52919 train acc: 0.953
# 12th epoch-23th iteration: train loss: 1.51602 train acc: 0.964
# 12th epoch-24th iteration: train loss: 1.52027 train acc: 0.963
# 12th epoch-25th iteration: train loss: 1.52811 train acc: 0.956
# 12th epoch-26th iteration: train loss: 1.53146 train acc: 0.950
# 12th epoch-27th iteration: train loss: 1.50766 train acc: 0.970
# 12th epoch-28th iteration: train loss: 1.51035 train acc: 0.970
# 12th epoch-29th iteration: train loss: 1.51575 train acc: 0.965
# 12th epoch-30th iteration: train loss: 1.51829 train acc: 0.962
# 12th epoch-31th iteration: train loss: 1.52531 train acc: 0.957
# 12th epoch-32th iteration: train loss: 1.52396 train acc: 0.954
# 12th epoch-33th iteration: train loss: 1.51309 train acc: 0.968
# 12th epoch-34th iteration: train loss: 1.52332 train acc: 0.954
# 12th epoch-35th iteration: train loss: 1.52646 train acc: 0.948
# 12th epoch-36th iteration: train loss: 1.51623 train acc: 0.962
# 12th epoch-37th iteration: train loss: 1.52535 train acc: 0.954
# 12th epoch-38th iteration: train loss: 1.52220 train acc: 0.963
# 12th epoch-39th iteration: train loss: 1.52754 train acc: 0.950
# 12th epoch-40th iteration: train loss: 1.52206 train acc: 0.953
# 12th epoch-41th iteration: train loss: 1.53003 train acc: 0.954
# 12th epoch-42th iteration: train loss: 1.52073 train acc: 0.958
# 12th epoch-43th iteration: train loss: 1.52539 train acc: 0.953
# 12th epoch-44th iteration: train loss: 1.52581 train acc: 0.956
# 12th epoch-45th iteration: train loss: 1.50895 train acc: 0.971
# 12th epoch-46th iteration: train loss: 1.50504 train acc: 0.973
# 12th epoch-47th iteration: train loss: 1.51246 train acc: 0.968
# 12th epoch-48th iteration: train loss: 1.49769 train acc: 0.979
# 12th epoch-49th iteration: train loss: 1.50047 train acc: 0.975
# valid loss: 1.52209 valid acc: 0.955
# 13th epoch-0th iteration: train loss: 1.52297 train acc: 0.958
# 13th epoch-1th iteration: train loss: 1.51013 train acc: 0.968
# 13th epoch-2th iteration: train loss: 1.51087 train acc: 0.969
# 13th epoch-3th iteration: train loss: 1.51283 train acc: 0.967
# 13th epoch-4th iteration: train loss: 1.51833 train acc: 0.962
# 13th epoch-5th iteration: train loss: 1.51783 train acc: 0.967
# 13th epoch-6th iteration: train loss: 1.52049 train acc: 0.962
# 13th epoch-7th iteration: train loss: 1.53772 train acc: 0.948
# 13th epoch-8th iteration: train loss: 1.51036 train acc: 0.970
# 13th epoch-9th iteration: train loss: 1.51659 train acc: 0.963
# 13th epoch-10th iteration: train loss: 1.52757 train acc: 0.951
# 13th epoch-11th iteration: train loss: 1.52361 train acc: 0.962
# 13th epoch-12th iteration: train loss: 1.52429 train acc: 0.954
# 13th epoch-13th iteration: train loss: 1.51689 train acc: 0.964
# 13th epoch-14th iteration: train loss: 1.52047 train acc: 0.966
# 13th epoch-15th iteration: train loss: 1.50840 train acc: 0.973
# 13th epoch-16th iteration: train loss: 1.51256 train acc: 0.963
# 13th epoch-17th iteration: train loss: 1.51324 train acc: 0.963
# 13th epoch-18th iteration: train loss: 1.51819 train acc: 0.963
# 13th epoch-19th iteration: train loss: 1.50893 train acc: 0.965
# 13th epoch-20th iteration: train loss: 1.51970 train acc: 0.963
# 13th epoch-21th iteration: train loss: 1.51420 train acc: 0.968
# 13th epoch-22th iteration: train loss: 1.52684 train acc: 0.950
# 13th epoch-23th iteration: train loss: 1.51545 train acc: 0.966
# 13th epoch-24th iteration: train loss: 1.51961 train acc: 0.963
# 13th epoch-25th iteration: train loss: 1.52744 train acc: 0.960
# 13th epoch-26th iteration: train loss: 1.53037 train acc: 0.950
# 13th epoch-27th iteration: train loss: 1.50747 train acc: 0.972
# 13th epoch-28th iteration: train loss: 1.51095 train acc: 0.968
# 13th epoch-29th iteration: train loss: 1.51474 train acc: 0.967
# 13th epoch-30th iteration: train loss: 1.51790 train acc: 0.965
# 13th epoch-31th iteration: train loss: 1.52468 train acc: 0.953
# 13th epoch-32th iteration: train loss: 1.52188 train acc: 0.958
# 13th epoch-33th iteration: train loss: 1.51179 train acc: 0.971
# 13th epoch-34th iteration: train loss: 1.52186 train acc: 0.955
# 13th epoch-35th iteration: train loss: 1.52531 train acc: 0.948
# 13th epoch-36th iteration: train loss: 1.51510 train acc: 0.962
# 13th epoch-37th iteration: train loss: 1.52353 train acc: 0.955
# 13th epoch-38th iteration: train loss: 1.52190 train acc: 0.962
# 13th epoch-39th iteration: train loss: 1.52707 train acc: 0.953
# 13th epoch-40th iteration: train loss: 1.52134 train acc: 0.955
# 13th epoch-41th iteration: train loss: 1.52815 train acc: 0.957
# 13th epoch-42th iteration: train loss: 1.51957 train acc: 0.958
# 13th epoch-43th iteration: train loss: 1.52508 train acc: 0.954
# 13th epoch-44th iteration: train loss: 1.52477 train acc: 0.953
# 13th epoch-45th iteration: train loss: 1.50776 train acc: 0.973
# 13th epoch-46th iteration: train loss: 1.50446 train acc: 0.974
# 13th epoch-47th iteration: train loss: 1.51251 train acc: 0.970
# 13th epoch-48th iteration: train loss: 1.49785 train acc: 0.981
# 13th epoch-49th iteration: train loss: 1.49873 train acc: 0.978
# valid loss: 1.52353 valid acc: 0.953
# 14th epoch-0th iteration: train loss: 1.52376 train acc: 0.958
# 14th epoch-1th iteration: train loss: 1.50966 train acc: 0.968
# 14th epoch-2th iteration: train loss: 1.51066 train acc: 0.972
# 14th epoch-3th iteration: train loss: 1.51377 train acc: 0.964
# 14th epoch-4th iteration: train loss: 1.51815 train acc: 0.961
# 14th epoch-5th iteration: train loss: 1.51767 train acc: 0.968
# 14th epoch-6th iteration: train loss: 1.51953 train acc: 0.965
# 14th epoch-7th iteration: train loss: 1.53800 train acc: 0.947
# 14th epoch-8th iteration: train loss: 1.51019 train acc: 0.970
# 14th epoch-9th iteration: train loss: 1.51538 train acc: 0.963
# 14th epoch-10th iteration: train loss: 1.52601 train acc: 0.953
# 14th epoch-11th iteration: train loss: 1.52258 train acc: 0.956
# 14th epoch-12th iteration: train loss: 1.52307 train acc: 0.960
# 14th epoch-13th iteration: train loss: 1.51708 train acc: 0.963
# 14th epoch-14th iteration: train loss: 1.51993 train acc: 0.965
# 14th epoch-15th iteration: train loss: 1.50782 train acc: 0.972
# 14th epoch-16th iteration: train loss: 1.51213 train acc: 0.963
# 14th epoch-17th iteration: train loss: 1.51184 train acc: 0.964
# 14th epoch-18th iteration: train loss: 1.52008 train acc: 0.962
# 14th epoch-19th iteration: train loss: 1.50761 train acc: 0.970
# 14th epoch-20th iteration: train loss: 1.51879 train acc: 0.964
# 14th epoch-21th iteration: train loss: 1.51429 train acc: 0.966
# 14th epoch-22th iteration: train loss: 1.52651 train acc: 0.951
# 14th epoch-23th iteration: train loss: 1.51468 train acc: 0.963
# 14th epoch-24th iteration: train loss: 1.51890 train acc: 0.963
# 14th epoch-25th iteration: train loss: 1.52736 train acc: 0.960
# 14th epoch-26th iteration: train loss: 1.52916 train acc: 0.951
# 14th epoch-27th iteration: train loss: 1.50764 train acc: 0.973
# 14th epoch-28th iteration: train loss: 1.51122 train acc: 0.968
# 14th epoch-29th iteration: train loss: 1.51382 train acc: 0.970
# 14th epoch-30th iteration: train loss: 1.51845 train acc: 0.963
# 14th epoch-31th iteration: train loss: 1.52353 train acc: 0.955
# 14th epoch-32th iteration: train loss: 1.52007 train acc: 0.963
# 14th epoch-33th iteration: train loss: 1.51101 train acc: 0.973
# 14th epoch-34th iteration: train loss: 1.51996 train acc: 0.961
# 14th epoch-35th iteration: train loss: 1.52467 train acc: 0.949
# 14th epoch-36th iteration: train loss: 1.51433 train acc: 0.962
# 14th epoch-37th iteration: train loss: 1.52292 train acc: 0.954
# 14th epoch-38th iteration: train loss: 1.52156 train acc: 0.963
# 14th epoch-39th iteration: train loss: 1.52641 train acc: 0.953
# 14th epoch-40th iteration: train loss: 1.52142 train acc: 0.958
# 14th epoch-41th iteration: train loss: 1.52751 train acc: 0.957
# 14th epoch-42th iteration: train loss: 1.51855 train acc: 0.960
# 14th epoch-43th iteration: train loss: 1.52572 train acc: 0.954
# 14th epoch-44th iteration: train loss: 1.52389 train acc: 0.959
# 14th epoch-45th iteration: train loss: 1.50777 train acc: 0.973
# 14th epoch-46th iteration: train loss: 1.50428 train acc: 0.972
# 14th epoch-47th iteration: train loss: 1.51252 train acc: 0.969
# 14th epoch-48th iteration: train loss: 1.49874 train acc: 0.980
# 14th epoch-49th iteration: train loss: 1.49767 train acc: 0.978
# valid loss: 1.52587 valid acc: 0.951
# 15th epoch-0th iteration: train loss: 1.52520 train acc: 0.953
# ...
# 45th epoch-3th iteration: train loss: 1.50939 train acc: 0.966
# 45th epoch-4th iteration: train loss: 1.51491 train acc: 0.963
# 45th epoch-5th iteration: train loss: 1.52060 train acc: 0.958
# 45th epoch-6th iteration: train loss: 1.51652 train acc: 0.964
# 45th epoch-7th iteration: train loss: 1.52750 train acc: 0.956
# 45th epoch-8th iteration: train loss: 1.50776 train acc: 0.972
# 45th epoch-9th iteration: train loss: 1.51766 train acc: 0.964
# 45th epoch-10th iteration: train loss: 1.52709 train acc: 0.951
# 45th epoch-11th iteration: train loss: 1.51676 train acc: 0.962
# 45th epoch-12th iteration: train loss: 1.52037 train acc: 0.963
# 45th epoch-13th iteration: train loss: 1.51465 train acc: 0.963
# 45th epoch-14th iteration: train loss: 1.51800 train acc: 0.967
# 45th epoch-15th iteration: train loss: 1.50571 train acc: 0.973
# 45th epoch-16th iteration: train loss: 1.51150 train acc: 0.963
# 45th epoch-17th iteration: train loss: 1.51200 train acc: 0.962
# 45th epoch-18th iteration: train loss: 1.51795 train acc: 0.958
# 45th epoch-19th iteration: train loss: 1.50648 train acc: 0.973
# 45th epoch-20th iteration: train loss: 1.51589 train acc: 0.965
# 45th epoch-21th iteration: train loss: 1.50850 train acc: 0.971
# 45th epoch-22th iteration: train loss: 1.52311 train acc: 0.958
# 45th epoch-23th iteration: train loss: 1.51591 train acc: 0.963
# 45th epoch-24th iteration: train loss: 1.51670 train acc: 0.962
# 45th epoch-25th iteration: train loss: 1.52389 train acc: 0.957
# 45th epoch-26th iteration: train loss: 1.52543 train acc: 0.957
# 45th epoch-27th iteration: train loss: 1.51201 train acc: 0.963
# 45th epoch-28th iteration: train loss: 1.50647 train acc: 0.975
# 45th epoch-29th iteration: train loss: 1.51210 train acc: 0.963
# 45th epoch-30th iteration: train loss: 1.51586 train acc: 0.965
# 45th epoch-31th iteration: train loss: 1.52521 train acc: 0.957
# 45th epoch-32th iteration: train loss: 1.51652 train acc: 0.959
# 45th epoch-33th iteration: train loss: 1.50566 train acc: 0.975
# 45th epoch-34th iteration: train loss: 1.52154 train acc: 0.954
# 45th epoch-35th iteration: train loss: 1.51495 train acc: 0.963
# 45th epoch-36th iteration: train loss: 1.51169 train acc: 0.966
# 45th epoch-37th iteration: train loss: 1.51213 train acc: 0.963
# 45th epoch-38th iteration: train loss: 1.51686 train acc: 0.961
# 45th epoch-39th iteration: train loss: 1.51753 train acc: 0.960
# 45th epoch-40th iteration: train loss: 1.51644 train acc: 0.961
# 45th epoch-41th iteration: train loss: 1.52456 train acc: 0.955
# 45th epoch-42th iteration: train loss: 1.51042 train acc: 0.968
# 45th epoch-43th iteration: train loss: 1.51891 train acc: 0.957
# 45th epoch-44th iteration: train loss: 1.51950 train acc: 0.958
# 45th epoch-45th iteration: train loss: 1.50561 train acc: 0.978
# 45th epoch-46th iteration: train loss: 1.50585 train acc: 0.971
# 45th epoch-47th iteration: train loss: 1.50588 train acc: 0.971
# 45th epoch-48th iteration: train loss: 1.49424 train acc: 0.980
# 45th epoch-49th iteration: train loss: 1.49677 train acc: 0.976
# valid loss: 1.52584 valid acc: 0.951
# 46th epoch-0th iteration: train loss: 1.52560 train acc: 0.956
# 46th epoch-1th iteration: train loss: 1.50750 train acc: 0.968
# 46th epoch-2th iteration: train loss: 1.50292 train acc: 0.970
# 46th epoch-3th iteration: train loss: 1.50866 train acc: 0.968
# 46th epoch-4th iteration: train loss: 1.51396 train acc: 0.960
# 46th epoch-5th iteration: train loss: 1.51936 train acc: 0.963
# 46th epoch-6th iteration: train loss: 1.52053 train acc: 0.963
# 46th epoch-7th iteration: train loss: 1.52666 train acc: 0.956
# 46th epoch-8th iteration: train loss: 1.50649 train acc: 0.971
# 46th epoch-9th iteration: train loss: 1.51952 train acc: 0.960
# 46th epoch-10th iteration: train loss: 1.52904 train acc: 0.948
# 46th epoch-11th iteration: train loss: 1.51879 train acc: 0.960
# 46th epoch-12th iteration: train loss: 1.52018 train acc: 0.962
# 46th epoch-13th iteration: train loss: 1.51475 train acc: 0.962
# 46th epoch-14th iteration: train loss: 1.51575 train acc: 0.969
# 46th epoch-15th iteration: train loss: 1.50914 train acc: 0.972
# 46th epoch-16th iteration: train loss: 1.51141 train acc: 0.967
# 46th epoch-17th iteration: train loss: 1.51049 train acc: 0.965
# 46th epoch-18th iteration: train loss: 1.51775 train acc: 0.957
# 46th epoch-19th iteration: train loss: 1.50561 train acc: 0.972
# 46th epoch-20th iteration: train loss: 1.51542 train acc: 0.965
# 46th epoch-21th iteration: train loss: 1.51022 train acc: 0.969
# 46th epoch-22th iteration: train loss: 1.52325 train acc: 0.953
# 46th epoch-23th iteration: train loss: 1.51635 train acc: 0.958
# 46th epoch-24th iteration: train loss: 1.51408 train acc: 0.966
# 46th epoch-25th iteration: train loss: 1.52311 train acc: 0.956
# 46th epoch-26th iteration: train loss: 1.52633 train acc: 0.955
# 46th epoch-27th iteration: train loss: 1.51244 train acc: 0.958
# 46th epoch-28th iteration: train loss: 1.50551 train acc: 0.973
# 46th epoch-29th iteration: train loss: 1.51147 train acc: 0.964
# 46th epoch-30th iteration: train loss: 1.51480 train acc: 0.963
# 46th epoch-31th iteration: train loss: 1.52302 train acc: 0.960
# 46th epoch-32th iteration: train loss: 1.51594 train acc: 0.961
# 46th epoch-33th iteration: train loss: 1.50518 train acc: 0.973
# 46th epoch-34th iteration: train loss: 1.51959 train acc: 0.957
# 46th epoch-35th iteration: train loss: 1.51503 train acc: 0.960
# 46th epoch-36th iteration: train loss: 1.51109 train acc: 0.967
# 46th epoch-37th iteration: train loss: 1.51475 train acc: 0.963
# 46th epoch-38th iteration: train loss: 1.51640 train acc: 0.962
# 46th epoch-39th iteration: train loss: 1.51863 train acc: 0.958
# 46th epoch-40th iteration: train loss: 1.51498 train acc: 0.963
# 46th epoch-41th iteration: train loss: 1.52316 train acc: 0.958
# 46th epoch-42th iteration: train loss: 1.51086 train acc: 0.969
# 46th epoch-43th iteration: train loss: 1.51849 train acc: 0.959
# 46th epoch-44th iteration: train loss: 1.51980 train acc: 0.959
# 46th epoch-45th iteration: train loss: 1.50496 train acc: 0.976
# 46th epoch-46th iteration: train loss: 1.50603 train acc: 0.968
# 46th epoch-47th iteration: train loss: 1.50742 train acc: 0.973
# 46th epoch-48th iteration: train loss: 1.49736 train acc: 0.976
# 46th epoch-49th iteration: train loss: 1.49473 train acc: 0.978
# valid loss: 1.52110 valid acc: 0.956
# 47th epoch-0th iteration: train loss: 1.52162 train acc: 0.957
# 47th epoch-1th iteration: train loss: 1.50857 train acc: 0.965
# 47th epoch-2th iteration: train loss: 1.50242 train acc: 0.972
# 47th epoch-3th iteration: train loss: 1.50798 train acc: 0.968
# 47th epoch-4th iteration: train loss: 1.51089 train acc: 0.964
# 47th epoch-5th iteration: train loss: 1.51445 train acc: 0.966
# 47th epoch-6th iteration: train loss: 1.52334 train acc: 0.960
# 47th epoch-7th iteration: train loss: 1.52727 train acc: 0.950
# 47th epoch-8th iteration: train loss: 1.50418 train acc: 0.971
# 47th epoch-9th iteration: train loss: 1.51640 train acc: 0.962
# 47th epoch-10th iteration: train loss: 1.52643 train acc: 0.953
# 47th epoch-11th iteration: train loss: 1.52167 train acc: 0.958
# 47th epoch-12th iteration: train loss: 1.52045 train acc: 0.961
# 47th epoch-13th iteration: train loss: 1.51236 train acc: 0.966
# 47th epoch-14th iteration: train loss: 1.51525 train acc: 0.969
# 47th epoch-15th iteration: train loss: 1.50752 train acc: 0.972
# 47th epoch-16th iteration: train loss: 1.51408 train acc: 0.965
# 47th epoch-17th iteration: train loss: 1.50968 train acc: 0.966
# 47th epoch-18th iteration: train loss: 1.52088 train acc: 0.960
# 47th epoch-19th iteration: train loss: 1.50524 train acc: 0.971
# 47th epoch-20th iteration: train loss: 1.51324 train acc: 0.969
# 47th epoch-21th iteration: train loss: 1.51136 train acc: 0.970
# 47th epoch-22th iteration: train loss: 1.52432 train acc: 0.956
# 47th epoch-23th iteration: train loss: 1.51783 train acc: 0.959
# 47th epoch-24th iteration: train loss: 1.51473 train acc: 0.960
# 47th epoch-25th iteration: train loss: 1.52193 train acc: 0.961
# 47th epoch-26th iteration: train loss: 1.52639 train acc: 0.957
# 47th epoch-27th iteration: train loss: 1.51379 train acc: 0.960
# 47th epoch-28th iteration: train loss: 1.50747 train acc: 0.969
# 47th epoch-29th iteration: train loss: 1.51341 train acc: 0.963
# 47th epoch-30th iteration: train loss: 1.51405 train acc: 0.966
# 47th epoch-31th iteration: train loss: 1.52428 train acc: 0.957
# 47th epoch-32th iteration: train loss: 1.51797 train acc: 0.959
# 47th epoch-33th iteration: train loss: 1.50602 train acc: 0.972
# 47th epoch-34th iteration: train loss: 1.52019 train acc: 0.958
# 47th epoch-35th iteration: train loss: 1.51717 train acc: 0.960
# 47th epoch-36th iteration: train loss: 1.51299 train acc: 0.963
# 47th epoch-37th iteration: train loss: 1.51558 train acc: 0.958
# 47th epoch-38th iteration: train loss: 1.51606 train acc: 0.963
# 47th epoch-39th iteration: train loss: 1.52155 train acc: 0.957
# 47th epoch-40th iteration: train loss: 1.51705 train acc: 0.960
# 47th epoch-41th iteration: train loss: 1.52257 train acc: 0.957
# 47th epoch-42th iteration: train loss: 1.51250 train acc: 0.968
# 47th epoch-43th iteration: train loss: 1.51940 train acc: 0.958
# 47th epoch-44th iteration: train loss: 1.52269 train acc: 0.957
# 47th epoch-45th iteration: train loss: 1.50569 train acc: 0.973
# 47th epoch-46th iteration: train loss: 1.50671 train acc: 0.968
# 47th epoch-47th iteration: train loss: 1.50728 train acc: 0.969
# 47th epoch-48th iteration: train loss: 1.50007 train acc: 0.974
# 47th epoch-49th iteration: train loss: 1.49520 train acc: 0.980
# valid loss: 1.51779 valid acc: 0.958
# 48th epoch-0th iteration: train loss: 1.51871 train acc: 0.961
# 48th epoch-1th iteration: train loss: 1.50823 train acc: 0.968
# 48th epoch-2th iteration: train loss: 1.50288 train acc: 0.972
# 48th epoch-3th iteration: train loss: 1.50897 train acc: 0.968
# 48th epoch-4th iteration: train loss: 1.51255 train acc: 0.963
# 48th epoch-5th iteration: train loss: 1.51529 train acc: 0.963
# 48th epoch-6th iteration: train loss: 1.52267 train acc: 0.962
# 48th epoch-7th iteration: train loss: 1.53079 train acc: 0.945
# 48th epoch-8th iteration: train loss: 1.50395 train acc: 0.972
# 48th epoch-9th iteration: train loss: 1.51740 train acc: 0.961
# 48th epoch-10th iteration: train loss: 1.52555 train acc: 0.953
# 48th epoch-11th iteration: train loss: 1.52357 train acc: 0.957
# 48th epoch-12th iteration: train loss: 1.52111 train acc: 0.960
# 48th epoch-13th iteration: train loss: 1.51087 train acc: 0.967
# 48th epoch-14th iteration: train loss: 1.51798 train acc: 0.968
# 48th epoch-15th iteration: train loss: 1.50548 train acc: 0.968
# 48th epoch-16th iteration: train loss: 1.51469 train acc: 0.962
# 48th epoch-17th iteration: train loss: 1.51072 train acc: 0.966
# 48th epoch-18th iteration: train loss: 1.51925 train acc: 0.961
# 48th epoch-19th iteration: train loss: 1.50778 train acc: 0.966
# 48th epoch-20th iteration: train loss: 1.51280 train acc: 0.968
# 48th epoch-21th iteration: train loss: 1.51225 train acc: 0.971
# 48th epoch-22th iteration: train loss: 1.52801 train acc: 0.949
# 48th epoch-23th iteration: train loss: 1.51489 train acc: 0.963
# 48th epoch-24th iteration: train loss: 1.51724 train acc: 0.960
# 48th epoch-25th iteration: train loss: 1.52620 train acc: 0.952
# 48th epoch-26th iteration: train loss: 1.52459 train acc: 0.960
# 48th epoch-27th iteration: train loss: 1.51475 train acc: 0.959
# 48th epoch-28th iteration: train loss: 1.51131 train acc: 0.965
# 48th epoch-29th iteration: train loss: 1.51994 train acc: 0.956
# 48th epoch-30th iteration: train loss: 1.51404 train acc: 0.965
# 48th epoch-31th iteration: train loss: 1.52391 train acc: 0.958
# 48th epoch-32th iteration: train loss: 1.52372 train acc: 0.958
# 48th epoch-33th iteration: train loss: 1.50967 train acc: 0.971
# 48th epoch-34th iteration: train loss: 1.52053 train acc: 0.955
# 48th epoch-35th iteration: train loss: 1.51914 train acc: 0.962
# 48th epoch-36th iteration: train loss: 1.51660 train acc: 0.959
# 48th epoch-37th iteration: train loss: 1.52254 train acc: 0.953
# 48th epoch-38th iteration: train loss: 1.51576 train acc: 0.961
# 48th epoch-39th iteration: train loss: 1.52205 train acc: 0.959
# 48th epoch-40th iteration: train loss: 1.52246 train acc: 0.955
# 48th epoch-41th iteration: train loss: 1.52668 train acc: 0.952
# 48th epoch-42th iteration: train loss: 1.52271 train acc: 0.955
# 48th epoch-43th iteration: train loss: 1.51682 train acc: 0.958
# 48th epoch-44th iteration: train loss: 1.52660 train acc: 0.950
# 48th epoch-45th iteration: train loss: 1.50948 train acc: 0.971
# 48th epoch-46th iteration: train loss: 1.50945 train acc: 0.966
# 48th epoch-47th iteration: train loss: 1.51212 train acc: 0.963
# 48th epoch-48th iteration: train loss: 1.49761 train acc: 0.978
# 48th epoch-49th iteration: train loss: 1.49863 train acc: 0.977
# valid loss: 1.51775 valid acc: 0.959
# 49th epoch-0th iteration: train loss: 1.52045 train acc: 0.958
# 49th epoch-1th iteration: train loss: 1.50772 train acc: 0.965
# 49th epoch-2th iteration: train loss: 1.50242 train acc: 0.972
# 49th epoch-3th iteration: train loss: 1.50644 train acc: 0.972
# 49th epoch-4th iteration: train loss: 1.51529 train acc: 0.962
# 49th epoch-5th iteration: train loss: 1.52547 train acc: 0.952
# 49th epoch-6th iteration: train loss: 1.51914 train acc: 0.963
# 49th epoch-7th iteration: train loss: 1.52757 train acc: 0.951
# 49th epoch-8th iteration: train loss: 1.50770 train acc: 0.970
# 49th epoch-9th iteration: train loss: 1.51964 train acc: 0.958
# 49th epoch-10th iteration: train loss: 1.53038 train acc: 0.946
# 49th epoch-11th iteration: train loss: 1.51574 train acc: 0.965
# 49th epoch-12th iteration: train loss: 1.51928 train acc: 0.967
# 49th epoch-13th iteration: train loss: 1.51180 train acc: 0.964
# 49th epoch-14th iteration: train loss: 1.51604 train acc: 0.967
# 49th epoch-15th iteration: train loss: 1.50604 train acc: 0.968
# 49th epoch-16th iteration: train loss: 1.51050 train acc: 0.963
# 49th epoch-17th iteration: train loss: 1.51140 train acc: 0.964
# 49th epoch-18th iteration: train loss: 1.52088 train acc: 0.961
# 49th epoch-19th iteration: train loss: 1.50375 train acc: 0.973
# 49th epoch-20th iteration: train loss: 1.51057 train acc: 0.969
# 49th epoch-21th iteration: train loss: 1.51210 train acc: 0.968
# 49th epoch-22th iteration: train loss: 1.52896 train acc: 0.944
# 49th epoch-23th iteration: train loss: 1.51320 train acc: 0.964
# 49th epoch-24th iteration: train loss: 1.51340 train acc: 0.964
# 49th epoch-25th iteration: train loss: 1.52304 train acc: 0.959
# 49th epoch-26th iteration: train loss: 1.52546 train acc: 0.958
# 49th epoch-27th iteration: train loss: 1.51057 train acc: 0.963
# 49th epoch-28th iteration: train loss: 1.50571 train acc: 0.968
# 49th epoch-29th iteration: train loss: 1.51281 train acc: 0.965
# 49th epoch-30th iteration: train loss: 1.51370 train acc: 0.963
# 49th epoch-31th iteration: train loss: 1.51709 train acc: 0.957
# 49th epoch-32th iteration: train loss: 1.51633 train acc: 0.960
# 49th epoch-33th iteration: train loss: 1.50643 train acc: 0.978
# 49th epoch-34th iteration: train loss: 1.52086 train acc: 0.959
# 49th epoch-35th iteration: train loss: 1.51831 train acc: 0.960
# 49th epoch-36th iteration: train loss: 1.51108 train acc: 0.963
# 49th epoch-37th iteration: train loss: 1.51708 train acc: 0.963
# 49th epoch-38th iteration: train loss: 1.51748 train acc: 0.962
# 49th epoch-39th iteration: train loss: 1.52171 train acc: 0.953
# 49th epoch-40th iteration: train loss: 1.51601 train acc: 0.961
# 49th epoch-41th iteration: train loss: 1.52087 train acc: 0.958
# 49th epoch-42th iteration: train loss: 1.51798 train acc: 0.960
# 49th epoch-43th iteration: train loss: 1.51659 train acc: 0.963
# 49th epoch-44th iteration: train loss: 1.51950 train acc: 0.957
# 49th epoch-45th iteration: train loss: 1.50403 train acc: 0.971
# 49th epoch-46th iteration: train loss: 1.50603 train acc: 0.968
# 49th epoch-47th iteration: train loss: 1.50910 train acc: 0.969
# 49th epoch-48th iteration: train loss: 1.49709 train acc: 0.977
# 49th epoch-49th iteration: train loss: 1.49373 train acc: 0.983
# valid loss: 1.51451 valid acc: 0.961

# %%
print(f"train acc: {acc_tr}, test acc: {acc_valid}, train loss: {loss_tr}, valid loss: {loss_valid}")
# Out:
# train acc: 0.9825, test acc: 0.9614, train loss: 1.493728756904602, valid loss: 1.5145128965377808

# %%
'''
n_depth_per_block = model[0].n_depth_per_block
coeff = model[1].coeff
prefix_name = dataset_name+"_"+"qnn"+str(n_depth_per_block)+"_c"+str(coeff)+"_"+str(n_qubits)+"qubits_"
if True:
    pd.DataFrame(all_tr_acc).to_csv(dataset_name+"_"+str(n_depth_per_block)+"_qnn_c35_"+str(n_qubits)+"qubits_tr_acc.csv", index=False)
    pd.DataFrame(all_valid_acc).to_csv(dataset_name+"_"+str(n_depth_per_block)+"_qnn_c35_"+str(n_qubits)+"qubits_valid_acc.csv", index=False)
    pd.DataFrame(all_tr_loss).to_csv(dataset_name+"_"+str(n_depth_per_block)+"_qnn_c35_"+str(n_qubits)+"qubits_tr_loss.csv", index=False)
    pd.DataFrame(all_valid_loss).to_csv(dataset_name+"_"+str(n_depth_per_block)+"_qnn_35_"+str(n_qubits)+"qubits_valid_loss.csv", index=False)
'''
# Out:
# '\nn_depth_per_block = model[0].n_depth_per_block\ncoeff = model[1].coeff\nprefix_name = dataset_name+"_"+"qnn"+str(n_depth_per_block)+"_c"+str(coeff)+"_"+str(n_qubits)+"qubits_"\nif True:\n    pd.DataFrame(all_tr_acc).to_csv(dataset_name+"_"+str(n_depth_per_block)+"_qnn_c35_"+str(n_qubits)+"qubits_tr_acc.csv", index=False)\n    pd.DataFrame(all_valid_acc).to_csv(dataset_name+"_"+str(n_depth_per_block)+"_qnn_c35_"+str(n_qubits)+"qubits_valid_acc.csv", index=False)\n    pd.DataFrame(all_tr_loss).to_csv(dataset_name+"_"+str(n_depth_per_block)+"_qnn_c35_"+str(n_qubits)+"qubits_tr_loss.csv", index=False)\n    pd.DataFrame(all_valid_loss).to_csv(dataset_name+"_"+str(n_depth_per_block)+"_qnn_35_"+str(n_qubits)+"qubits_valid_loss.csv", index=False)\n'

# %%
'''
lr0.005 d20 c5

'''
# Out:
# '\nlr0.005 d20 c5\n\n'
